# %% [markdown]
# # Data Prep

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv('original_dataset.csv')
df.head()

# %% [markdown]
# Checking DataFrame coloum type

# %%
df.info()

# %% [markdown]
# Spliting to train and test

# %%
train_df, test_df = train_test_split(df, test_size=0.3, random_state=25)

# %% [markdown]
# Read train data frame head

# %%
train_df.head()

# %% [markdown]
# Read test data frame head

# %%
test_df.head()

# %% [markdown]
# count train and test dataset

# %%
train_df.count()

# %%
test_df.count()

# %% [markdown]
# Export train and test dataframe

# %%
train_df.to_csv('train.csv', index = False)
test_df.to_csv('test.csv', index = False)

# %% [markdown]
# ## check n run

# %%
import pandas as pd

# %%
test_df  = pd.read_csv('test.csv')
train_df = pd.read_csv('train.csv')
additional_tweet = pd.read_csv('scraped_tweet_only.csv')

additional_tweet = additional_tweet.rename(columns={'Tweet': 'text'})

# %%
test_df.head()
# Out:
#                                                 text  label
# 0                   titisan air mata kini kekeringan      0
# 1  tni polri serta satpol pp dki menyambangi loka...      0
# 2   Gempa Mag:5.2, 31-Jan-21 16:28:55 WIB, Lok:5....      1
# 3  berbagai klaster penyebaran covid 19 kita moni...      0
# 4  saya tetap optimistis perekonomian indonesia a...      0

# %%
train_df.head()
# Out:
#                                                 text  label
# 0   Gempa Mag:4.8, 05/01/2021 18:56:21 (Pusat gem...      1
# 1  idha nama pemilik perusahaan yg bikin banjir a...      0
# 2  web kritik film danieldokter tariz aryaapepe r...      0
# 3  penjelasan fpi ganti nama jadi front persatuan...      0
# 4   Gempa Mag:5.0, 26-Oct-20 15:26:37 WIB, Lok:0....      1

# %%
additional_tweet.head()
# Out:
#                                                 text
# 0         akhirny naik gojek w malas banjir banjiran
# 1                                  Banjir luar dalam
# 2                          bismillah banjir congrats
# 3  huaa naek kreta ekonomi berjamjam super tegak ...
# 4  kata teman uwe,\nhari ini di laman jual beli O...

# %%
test_df.count()
# Out:
# text     1815
# label    1815
# dtype: int64

# %%
train_df.count()
# Out:
# text     4234
# label    4234
# dtype: int64

# %%
additional_tweet.count()
# Out:
# text    30000
# dtype: int64

# %% [markdown]
# # Building label using RubrixUI

# %% [markdown]
# ## Import Dataset to Rubrix

# %%
# run Docker
# run python -m rubrix on Terminal 1st

# %%
import rubrix as rb

# %%
# build records from the train dataset
records = [
    rb.TextClassificationRecord(
        text=row.text,
        #metadata={"split": "train"}
    )
    for i,row in additional_tweet.iterrows() #30,000
]

# build records from the test dataset with annotation
labels = ["NOT_ND", "ND"]
records += [
    rb.TextClassificationRecord(
        text=row.text,
        annotation=labels[row.label],
        #metadata={"split": "test"}
    )
    for i,row in test_df.iterrows() #~1,815
]

# log records to Rubrix
rb.log(records, name="ws_natural_disaster_v")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 31815/31815 [03:14<00:00, 163.77it/s]
# 31815 records logged to http://localhost:6900/datasets/rubrix/ws_natural_disaster_vi
# BulkResponse(dataset='ws_natural_disaster_vi', processed=31815, failed=0)

# %% [markdown]
# ## Evaluate Weak Label

# %%
from rubrix.labeling.text_classification import WeakLabels

weak_labels = WeakLabels(dataset="ws_natural_disaster_v")
# Out:
# Preparing rules: 100%|█████████████████████████████████████████████████████████████████| 44/44 [00:44<00:00,  1.00s/it]
# Applying rules: 100%|█████████████████████████████████████████████████████████| 31815/31815 [00:01<00:00, 29164.88it/s]

# %%
weak_labels.summary()
# Out:
#                   label  coverage  annotated_coverage  overlaps  conflicts  \
# wib                {ND}  0.021059            0.298072  0.017727   0.002860
# bmkg               {ND}  0.029954            0.277686  0.029923   0.011944
# lok                {ND}  0.010561            0.166391  0.010530   0.000283
# mmi                {ND}  0.010813            0.187879  0.010813   0.000126
# dirasakan          {ND}  0.011661            0.187328  0.011630   0.000503
# laut               {ND}  0.016030            0.129477  0.015936   0.007606
# berada             {ND}  0.012384            0.139394  0.012353   0.003929
# magnitud*          {ND}  0.008581            0.091460  0.008581   0.002609
# gempa              {ND}  0.245702            0.400551  0.192268   0.164388
# tsunami            {ND}  0.187459            0.077686  0.141506   0.128241
# angin              {ND}  0.087632            0.033609  0.087192   0.063335
# hujan              {ND}  0.068773            0.031956  0.062455   0.054754
# rumah              {ND}  0.042999            0.055096  0.039195   0.033789
# pusat              {ND}  0.013264            0.191185  0.013233   0.002043
# untuk          {NOT_ND}  0.041427            0.066667  0.037970   0.020871
# ada            {NOT_ND}  0.141411            0.070523  0.137765   0.101179
# itu            {NOT_ND}  0.054031            0.065014  0.051862   0.036084
# saya           {NOT_ND}  0.012070            0.041322  0.011473   0.006475
# kita           {NOT_ND}  0.032406            0.036915  0.031526   0.020053
# ngga           {NOT_ND}  0.008172            0.014876  0.007889   0.004212
# yang           {NOT_ND}  0.128681            0.122314  0.122112   0.079334
# yg             {NOT_ND}  0.112588            0.055647  0.105862   0.069967
# ini            {NOT_ND}  0.130976            0.111846  0.121641   0.077731
# lagi           {NOT_ND}  0.079931            0.022590  0.069338   0.044979
# dari           {NOT_ND}  0.072167            0.072727  0.067924   0.045167
# bencana        {NOT_ND}  0.059752            0.041322  0.056923   0.043313
# aku            {NOT_ND}  0.059815            0.020937  0.056294   0.040830
# aja            {NOT_ND}  0.055571            0.025895  0.052460   0.035769
# hari           {NOT_ND}  0.047745            0.029201  0.045859   0.028226
# semoga         {NOT_ND}  0.050888            0.015978  0.046770   0.027534
# tapi           {NOT_ND}  0.048625            0.029752  0.046016   0.031463
# udah           {NOT_ND}  0.049851            0.015427  0.046739   0.032532
# kalo           {NOT_ND}  0.046708            0.022039  0.044036   0.028289
# banget         {NOT_ND}  0.046267            0.005510  0.042433   0.027848
# apa            {NOT_ND}  0.041647            0.028099  0.040233   0.027974
# allah          {NOT_ND}  0.039415            0.014325  0.037278   0.025460
# sama           {NOT_ND}  0.037309            0.021488  0.035612   0.022285
# mana           {NOT_ND}  0.031086            0.008264  0.027408   0.016785
# gak            {NOT_ND}  0.050762            0.015978  0.047650   0.033506
# puting             {ND}  0.163351            0.062810  0.141788   0.114317
# bisa           {NOT_ND}  0.047839            0.040771  0.045513   0.027660
# gimana         {NOT_ND}  0.019456            0.006612  0.018953   0.014113
# tanah          {NOT_ND}  0.045576            0.030854  0.042810   0.029766
# juga           {NOT_ND}  0.042056            0.040771  0.039353   0.024957
# total      {NOT_ND, ND}  0.873519            0.868320  0.641898   0.422662
#
#            correct  incorrect  precision
# wib            537          4   0.992606
# bmkg           493         11   0.978175
# lok            302          0   1.000000
# mmi            341          0   1.000000
# dirasakan      339          1   0.997059
# laut           230          5   0.978723
# berada         248          5   0.980237
# magnitud*      164          2   0.987952
# gempa          520        207   0.715268
# tsunami        111         30   0.787234
# angin           56          5   0.918033
# hujan           42         16   0.724138
# rumah           79         21   0.790000
# pusat          339          8   0.976945
# untuk          106         15   0.876033
# ada            112         16   0.875000
# itu            106         12   0.898305
# saya            74          1   0.986667
# kita            61          6   0.910448
# ngga            27          0   1.000000
# yang           165         57   0.743243
# yg              92          9   0.910891
# ini            157         46   0.773399
# lagi            39          2   0.951220
# dari           100         32   0.757576
# bencana         47         28   0.626667
# aku             38          0   1.000000
# aja             47          0   1.000000
# hari            42         11   0.792453
# semoga          24          5   0.827586
# tapi            50          4   0.925926
# udah            27          1   0.964286
# kalo            39          1   0.975000
# banget           9          1   0.900000
# apa             49          2   0.960784
# allah           21          5   0.807692
# sama            37          2   0.948718
# mana            15          0   1.000000
# gak             26          3   0.896552
# puting         113          1   0.991228
# bisa            71          3   0.959459
# gimana          11          1   0.916667
# tanah           36         20   0.642857
# juga            64         10   0.864865
# total         5606        609   0.902011

# %%
from rubrix.labeling.text_classification import Snorkel

# create the label model
label_model = Snorkel(weak_labels)

# fit the model
label_model.fit()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1190.45epoch/s]

# %%
print(label_model.score(output_str=True))
# Out:
#               precision    recall  f1-score   support
#
#       NOT_ND       0.85      0.93      0.88       702
#           ND       0.94      0.86      0.90       874
#
#     accuracy                           0.89      1576
#    macro avg       0.89      0.89      0.89      1576
# weighted avg       0.90      0.89      0.89      1576

# %% [markdown]
# ## Prep train set

# %%
# get records with the predictions from the label model

# you can replace this line with
# records = rb.read_datasets(
#    load_dataset("rubrix/news", split="train"),
#    task="TextClassification",
# )
# we could also use the `weak_labels.label2int` dict

records = label_model.predict()
label2int = {"NOT_ND":0, "ND": 1}

# extract training data
X_train = [rec.text for rec in records]
y_train = [label2int[rec.prediction[0][0]] for rec in records]

# %%
# quick look at our training data with the weak labels from our label model
with pd.option_context('display.max_colwidth', None):
    display(pd.DataFrame({"text": X_train, "label": y_train}))
# Out:
#                                                                                                                                                                                                                                                                                           text  \
# 0                                                                                                                                                                                                             Bener2 ini jumat berkah dari malem ketemu malem ujan,semoga ga banjir ya Allah 😭
# 1                                                                                                                                                                                                              Bencana geologi : gempabumi, tsunami, letusan gunung berapi, dan tanah longsor.
# 2                                                                                                                                                                                                                                                         Liverpool Tsunami cidera ini namanya
# 3                                                                                                                                                                  Kemaren pas nerjang banjir kira kira 3/4 ban motor, di liatin sama orang orang. Mungkin dlm hati mereka “gila juga ni cewe”
# 4                                                                                                                                                                                                                                                                                    Gempa...?
# ...                                                                                                                                                                                                                                                                                        ...
# 26210                                                                                                                                                                                             pemda depok pas bikin berita angin puting beliung kata putingnya disensor jadi put*ng gak ya
# 26211                                                                                                                                                                                                                                                       puting beliung apa pitung beliung?
# 26212                                                                                                                                                                                                           alias bgsttt ati lu dari apaan mba😭 kuat bgt tahan api air tsunami badai gempa
# 26213                            Non stop gempa dari selasa. Semalem ga bisa tdur nyenyak. Puncaknya siang tadi gempa 5.4. Pengen donlot app bmkg tapi takut malah jadi parno 🥲 Hujan deres pula, ini orang2 mess pada rencana bermalam rame2 dibawah, biar klo gempa lagi keluarnya gampang 🥲
# 26214  jd kan aing bbrp hari ini di bogor krn ada project. trs emg lg ujan wae jd banjir + longsor gt. aing kaget bgt pas kelar skinkeran ko ada missed call dr mami gyan, jd aing callback gt. ternyata doi khawatir krn ak ga bls dn ga angkat telp jd dah mikir kl aku kebanjiran, HAPPYDH☺
#
#        label
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
# ...      ...
# 26210      1
# 26211      0
# 26212      0
# 26213      0
# 26214      0
#
# [26215 rows x 2 columns]

# %%
#records = label_model.predict()
#label2int = {'NOT_ND': 0, 'ND': 1}

# %%
autolabeled_data = pd.DataFrame(
    [
        {"text": rec.text, "label": label2int[rec.prediction[0][0]]}
        for rec in records
    ]
)

# %%
autolabeled_data
# Out:
#                                                     text  label
# 0      Bener2 ini jumat berkah dari malem ketemu male...      0
# 1      Bencana geologi : gempabumi, tsunami, letusan ...      0
# 2                   Liverpool Tsunami cidera ini namanya      0
# 3      Kemaren pas nerjang banjir kira kira 3/4 ban m...      0
# 4                                              Gempa...?      1
# ...                                                  ...    ...
# 26210  pemda depok pas bikin berita angin puting beli...      1
# 26211                 puting beliung apa pitung beliung?      0
# 26212  alias bgsttt ati lu dari apaan mba😭 kuat bgt t...      0
# 26213  Non stop gempa dari selasa. Semalem ga bisa td...      0
# 26214  jd kan aing bbrp hari ini di bogor krn ada pro...      0
#
# [26215 rows x 2 columns]

# %%
autolabeled_data.to_csv('autolabelled_dataset_v.csv', index = False)

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 

# Visualize the output (target)
plt.figure(figsize=(5,3))
colors = ["blue", "red"]

sns.countplot(x = 'label', data=autolabeled_data, palette=colors)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
import pandas as pd
df = weak_labels.summary()
df
# Out:
#                   label  coverage  annotated_coverage  overlaps  conflicts  \
# wib                {ND}  0.021059            0.298072  0.017727   0.002860
# bmkg               {ND}  0.029954            0.277686  0.029923   0.011944
# lok                {ND}  0.010561            0.166391  0.010530   0.000283
# mmi                {ND}  0.010813            0.187879  0.010813   0.000126
# dirasakan          {ND}  0.011661            0.187328  0.011630   0.000503
# laut               {ND}  0.016030            0.129477  0.015936   0.007606
# berada             {ND}  0.012384            0.139394  0.012353   0.003929
# magnitud*          {ND}  0.008581            0.091460  0.008581   0.002609
# gempa              {ND}  0.245702            0.400551  0.192268   0.164388
# tsunami            {ND}  0.187459            0.077686  0.141506   0.128241
# angin              {ND}  0.087632            0.033609  0.087192   0.063335
# hujan              {ND}  0.068773            0.031956  0.062455   0.054754
# rumah              {ND}  0.042999            0.055096  0.039195   0.033789
# pusat              {ND}  0.013264            0.191185  0.013233   0.002043
# untuk          {NOT_ND}  0.041427            0.066667  0.037970   0.020871
# ada            {NOT_ND}  0.141411            0.070523  0.137765   0.101179
# itu            {NOT_ND}  0.054031            0.065014  0.051862   0.036084
# saya           {NOT_ND}  0.012070            0.041322  0.011473   0.006475
# kita           {NOT_ND}  0.032406            0.036915  0.031526   0.020053
# ngga           {NOT_ND}  0.008172            0.014876  0.007889   0.004212
# yang           {NOT_ND}  0.128681            0.122314  0.122112   0.079334
# yg             {NOT_ND}  0.112588            0.055647  0.105862   0.069967
# ini            {NOT_ND}  0.130976            0.111846  0.121641   0.077731
# lagi           {NOT_ND}  0.079931            0.022590  0.069338   0.044979
# dari           {NOT_ND}  0.072167            0.072727  0.067924   0.045167
# bencana        {NOT_ND}  0.059752            0.041322  0.056923   0.043313
# aku            {NOT_ND}  0.059815            0.020937  0.056294   0.040830
# aja            {NOT_ND}  0.055571            0.025895  0.052460   0.035769
# hari           {NOT_ND}  0.047745            0.029201  0.045859   0.028226
# semoga         {NOT_ND}  0.050888            0.015978  0.046770   0.027534
# tapi           {NOT_ND}  0.048625            0.029752  0.046016   0.031463
# udah           {NOT_ND}  0.049851            0.015427  0.046739   0.032532
# kalo           {NOT_ND}  0.046708            0.022039  0.044036   0.028289
# banget         {NOT_ND}  0.046267            0.005510  0.042433   0.027848
# apa            {NOT_ND}  0.041647            0.028099  0.040233   0.027974
# allah          {NOT_ND}  0.039415            0.014325  0.037278   0.025460
# sama           {NOT_ND}  0.037309            0.021488  0.035612   0.022285
# mana           {NOT_ND}  0.031086            0.008264  0.027408   0.016785
# gak            {NOT_ND}  0.050762            0.015978  0.047650   0.033506
# puting             {ND}  0.163351            0.062810  0.141788   0.114317
# bisa           {NOT_ND}  0.047839            0.040771  0.045513   0.027660
# gimana         {NOT_ND}  0.019456            0.006612  0.018953   0.014113
# tanah          {NOT_ND}  0.045576            0.030854  0.042810   0.029766
# juga           {NOT_ND}  0.042056            0.040771  0.039353   0.024957
# total      {NOT_ND, ND}  0.873519            0.868320  0.641898   0.422662
#
#            correct  incorrect  precision
# wib            537          4   0.992606
# bmkg           493         11   0.978175
# lok            302          0   1.000000
# mmi            341          0   1.000000
# dirasakan      339          1   0.997059
# laut           230          5   0.978723
# berada         248          5   0.980237
# magnitud*      164          2   0.987952
# gempa          520        207   0.715268
# tsunami        111         30   0.787234
# angin           56          5   0.918033
# hujan           42         16   0.724138
# rumah           79         21   0.790000
# pusat          339          8   0.976945
# untuk          106         15   0.876033
# ada            112         16   0.875000
# itu            106         12   0.898305
# saya            74          1   0.986667
# kita            61          6   0.910448
# ngga            27          0   1.000000
# yang           165         57   0.743243
# yg              92          9   0.910891
# ini            157         46   0.773399
# lagi            39          2   0.951220
# dari           100         32   0.757576
# bencana         47         28   0.626667
# aku             38          0   1.000000
# aja             47          0   1.000000
# hari            42         11   0.792453
# semoga          24          5   0.827586
# tapi            50          4   0.925926
# udah            27          1   0.964286
# kalo            39          1   0.975000
# banget           9          1   0.900000
# apa             49          2   0.960784
# allah           21          5   0.807692
# sama            37          2   0.948718
# mana            15          0   1.000000
# gak             26          3   0.896552
# puting         113          1   0.991228
# bisa            71          3   0.959459
# gimana          11          1   0.916667
# tanah           36         20   0.642857
# juga            64         10   0.864865
# total         5606        609   0.902011

# %%
# Columns to round
columns_to_round = ['coverage', 'annotated_coverage', 'overlaps', 'conflicts', 'precision']

# Round numbers in selected columns to 5 decimal places
df[columns_to_round] = df[columns_to_round].round(decimals=2)

# %%
df.to_csv('weak_label.csv', index = True)
