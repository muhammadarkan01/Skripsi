# %% [markdown]
# # LSTM - Supervised Learning

# %% [markdown]
# ## Import lib

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ## LSTM model building

# %%
# Load the training and testing data
train_data = pd.read_csv('preprocessed_train.csv')
test_data = pd.read_csv('preprocessed_test.csv')

# Split the data into input and target
train_text = train_data['text'].values
train_labels = train_data['label'].values
test_text = test_data['text'].values
test_labels = test_data['label'].values

# Create a tokenizer and fit it on the training data
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(train_text)

# Convert the training and testing data into sequences of integers
train_sequences = tokenizer.texts_to_sequences(train_text)
test_sequences = tokenizer.texts_to_sequences(test_text)

# Pad the sequences to a fixed length
max_length = 100
train_data = pad_sequences(train_sequences, maxlen=max_length)
test_data = pad_sequences(test_sequences, maxlen=max_length)

# Define the LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(5000, 64, input_length=max_length),
    tf.keras.layers.LSTM(64, dropout=0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the training data
history = model.fit(train_data, train_labels, epochs=15, batch_size=32, validation_split=0.4)
# Out:
# Epoch 1/15
# 80/80 [==============================] - 5s 38ms/step - loss: 0.3886 - accuracy: 0.8554 - val_loss: 0.1755 - val_accuracy: 0.9398
# Epoch 2/15
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1302 - accuracy: 0.9571 - val_loss: 0.1476 - val_accuracy: 0.9522
# Epoch 3/15
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0728 - accuracy: 0.9724 - val_loss: 0.1413 - val_accuracy: 0.9545
# Epoch 4/15
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0422 - accuracy: 0.9858 - val_loss: 0.1393 - val_accuracy: 0.9569
# Epoch 5/15
# 80/80 [==============================] - 3s 43ms/step - loss: 0.0276 - accuracy: 0.9913 - val_loss: 0.1677 - val_accuracy: 0.9563
# Epoch 6/15
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0181 - accuracy: 0.9937 - val_loss: 0.1742 - val_accuracy: 0.9522
# Epoch 7/15
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0164 - accuracy: 0.9945 - val_loss: 0.1699 - val_accuracy: 0.9486
# Epoch 8/15
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0118 - accuracy: 0.9968 - val_loss: 0.2037 - val_accuracy: 0.9457
# Epoch 9/15
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.2283 - val_accuracy: 0.9527
# Epoch 10/15
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.2366 - val_accuracy: 0.9516
# Epoch 11/15
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.2572 - val_accuracy: 0.9474
# Epoch 12/15
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.1906 - val_accuracy: 0.9356
# Epoch 13/15
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0336 - accuracy: 0.9905 - val_loss: 0.1731 - val_accuracy: 0.9492
# Epoch 14/15
# 80/80 [==============================] - 3s 36ms/step - loss: 0.0086 - accuracy: 0.9988 - val_loss: 0.1973 - val_accuracy: 0.9510
# Epoch 15/15
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.2115 - val_accuracy: 0.9504

# %% [markdown]
# ## pyplot graph

# %%
# plot learning rate (model accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['acc', 'val_acc'], loc='upper left')
plt.show()

# %%
# plot learning rate (model loss)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ## Evaluation matrix

# %%
# Evaluate the model on the testing data
train_loss, train_acc = model.evaluate(train_data, train_labels)
print('Train accuracy:', train_acc)
# Evaluate the model on the testing data
test_loss, test_acc = model.evaluate(test_data, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 133/133 [==============================] - 1s 11ms/step - loss: 0.0878 - accuracy: 0.9790
# Train accuracy: 0.9789648056030273
# 57/57 [==============================] - 1s 11ms/step - loss: 0.2347 - accuracy: 0.9423
# Test accuracy: 0.9423183798789978

# %%
# Generate predictions on the testing data
y_pred = model.predict(test_data)
y_pred = np.round(y_pred).astype(int)

# Generate and print the classification report
print(classification_report(test_labels, y_pred))
# Out:
# 57/57 [==============================] - 1s 11ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       883
#            1       0.95      0.94      0.94       920
#
#     accuracy                           0.94      1803
#    macro avg       0.94      0.94      0.94      1803
# weighted avg       0.94      0.94      0.94      1803

# %%
# Generate and print the confusion matrix
conm = confusion_matrix(test_labels, y_pred)

# %%
plt.figure(figsize=(7, 5))
sns.heatmap(conm, annot=True, fmt='d', cmap='cool')
plt.show()
