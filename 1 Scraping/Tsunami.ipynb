# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

query = "tsunami lang:id -filter:links -filter:replies"
tweets = []
limit = 5000


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])
        
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
print(df)
# Out:
# C:\Users\arkan\AppData\Local\Temp\ipykernel_19828\4154450860.py:16: FutureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# C:\Users\arkan\AppData\Local\Temp\ipykernel_19828\4154450860.py:16: FutureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
#                           Date            User  \
# 0    2023-02-27 07:47:25+00:00       nastitikp
# 1    2023-02-27 07:46:16+00:00        mshdbhtr
# 2    2023-02-27 07:38:50+00:00       gunard___
# 3    2023-02-27 07:20:49+00:00         hyukalt
# 4    2023-02-27 07:11:06+00:00     rnoviantoro
# ...                        ...             ...
# 4995 2022-10-10 02:38:10+00:00       atiegrace
# 4996 2022-10-10 01:52:04+00:00          luqysm
# 4997 2022-10-10 01:25:55+00:00       RSipirock
# 4998 2022-10-10 00:26:47+00:00      KoFPLI_JOG
# 4999 2022-10-09 20:43:56+00:00  lYuliaRiyantil
#
#                                                   Tweet
# 0                         UDAH GAK SABAR TSUNAMI THROPY
# 1     Hallo @infoBMKG apakah ada tsunami trofi musim...
# 2     Sedih bgt gasi jas ujan baru beli baru sekali ...
# 3     temen w klo cerita drama bgt gak kuat. cerita ...
# 4            Banjiirr, badai,tsunami tropii caming soon
# ...                                                 ...
# 4995  lepas subuh tidur balik. mimpi pasal tsunami.t...
# 4996                    makk pengin ganti frame tsunami
# 4997  Bencana terbesar suatu bangsa bkn lah Tsunami,...
# 4998  Tips main FPL musim ini, pasang winger kiri mu...
# 4999  BMKG menyampaikan tak ada potensi tsunami usai...
#
# [5000 rows x 3 columns]

# %%
df
# Out:
#                           Date            User  \
# 0    2023-02-27 07:47:25+00:00       nastitikp
# 1    2023-02-27 07:46:16+00:00        mshdbhtr
# 2    2023-02-27 07:38:50+00:00       gunard___
# 3    2023-02-27 07:20:49+00:00         hyukalt
# 4    2023-02-27 07:11:06+00:00     rnoviantoro
# ...                        ...             ...
# 4995 2022-10-10 02:38:10+00:00       atiegrace
# 4996 2022-10-10 01:52:04+00:00          luqysm
# 4997 2022-10-10 01:25:55+00:00       RSipirock
# 4998 2022-10-10 00:26:47+00:00      KoFPLI_JOG
# 4999 2022-10-09 20:43:56+00:00  lYuliaRiyantil
#
#                                                   Tweet
# 0                         UDAH GAK SABAR TSUNAMI THROPY
# 1     Hallo @infoBMKG apakah ada tsunami trofi musim...
# 2     Sedih bgt gasi jas ujan baru beli baru sekali ...
# 3     temen w klo cerita drama bgt gak kuat. cerita ...
# 4            Banjiirr, badai,tsunami tropii caming soon
# ...                                                 ...
# 4995  lepas subuh tidur balik. mimpi pasal tsunami.t...
# 4996                    makk pengin ganti frame tsunami
# 4997  Bencana terbesar suatu bangsa bkn lah Tsunami,...
# 4998  Tips main FPL musim ini, pasang winger kiri mu...
# 4999  BMKG menyampaikan tak ada potensi tsunami usai...
#
# [5000 rows x 3 columns]

# %%
# to save to csv
df.to_csv('tsunami_tweets.csv')
