# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

query = "erupsi lang:id -filter:links -filter:replies"
tweets = []
limit = 10000


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])
        
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
print(df)
# Out:
# C:\Users\arkan\AppData\Local\Temp\ipykernel_3532\448075872.py:16: FutureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# C:\Users\arkan\AppData\Local\Temp\ipykernel_3532\448075872.py:16: FutureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
#                           Date           User  \
# 0    2023-02-26 10:42:24+00:00     dwikiprazz
# 1    2023-02-26 10:12:28+00:00     dwikiprazz
# 2    2023-02-26 08:12:27+00:00     dwikiprazz
# 3    2023-02-26 07:42:25+00:00     dwikiprazz
# 4    2023-02-26 06:42:24+00:00     dwikiprazz
# ...                        ...            ...
# 4995 2021-12-04 12:05:10+00:00    abebasudara
# 4996 2021-12-04 12:05:02+00:00  Baekhyunn1485
# 4997 2021-12-04 12:04:45+00:00    shyhunnie94
# 4998 2021-12-04 12:04:11+00:00   kookminpedia
# 4999 2021-12-04 12:03:56+00:00    arifhdyanto
#
#                                                   Tweet
# 0     AHY: Mari bersama kita berdoa untuk warga di w...
# 1     AHY: Saya instruksikan kepada kader #PartaiDem...
# 2     Demokrat Bergerak Ringankan Beban Masyarakat T...
# 3     Demokrat Kirim Tim Medis Bantu Korban Erupsi S...
# 4     DPC #PartaiDemokrat Surabaya memberikan bantua...
# ...                                                 ...
# 4995  stay safe buat temen" yg terkena dampak erupsi...
# 4996           Tolong dong foto korban erupsi di blur 😭
# 4997  ashskshs td smpt liat berita semeru erupsi kan...
# 4998  ditengah kebahagiaan ultah seokjin, Indonesia ...
# 4999  Doa terbaik unt saudaraku di lumajang dan seki...
#
# [5000 rows x 3 columns]

# %%
df
# Out:
#                           Date           User  \
# 0    2023-02-26 10:42:24+00:00     dwikiprazz
# 1    2023-02-26 10:12:28+00:00     dwikiprazz
# 2    2023-02-26 08:12:27+00:00     dwikiprazz
# 3    2023-02-26 07:42:25+00:00     dwikiprazz
# 4    2023-02-26 06:42:24+00:00     dwikiprazz
# ...                        ...            ...
# 4995 2021-12-04 12:05:10+00:00    abebasudara
# 4996 2021-12-04 12:05:02+00:00  Baekhyunn1485
# 4997 2021-12-04 12:04:45+00:00    shyhunnie94
# 4998 2021-12-04 12:04:11+00:00   kookminpedia
# 4999 2021-12-04 12:03:56+00:00    arifhdyanto
#
#                                                   Tweet
# 0     AHY: Mari bersama kita berdoa untuk warga di w...
# 1     AHY: Saya instruksikan kepada kader #PartaiDem...
# 2     Demokrat Bergerak Ringankan Beban Masyarakat T...
# 3     Demokrat Kirim Tim Medis Bantu Korban Erupsi S...
# 4     DPC #PartaiDemokrat Surabaya memberikan bantua...
# ...                                                 ...
# 4995  stay safe buat temen" yg terkena dampak erupsi...
# 4996           Tolong dong foto korban erupsi di blur 😭
# 4997  ashskshs td smpt liat berita semeru erupsi kan...
# 4998  ditengah kebahagiaan ultah seokjin, Indonesia ...
# 4999  Doa terbaik unt saudaraku di lumajang dan seki...
#
# [5000 rows x 3 columns]

# %%
# to save to csv
df.to_csv('erupsi_tweets.csv')
