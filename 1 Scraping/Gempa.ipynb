# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

query = "gempa -filter:links -filter:replies"
tweets = []
limit = 5000


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])
        
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
print(df)
# Out:
# C:\Users\arkan\AppData\Local\Temp\ipykernel_15420\1197906103.py:16: FutureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# C:\Users\arkan\AppData\Local\Temp\ipykernel_15420\1197906103.py:16: FutureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
#                           Date         User  \
# 0    2023-02-27 07:40:12+00:00     Nganuuuu
# 1    2023-02-27 07:23:11+00:00      GkPatuk
# 2    2023-02-27 07:04:02+00:00    peacheui_
# 3    2023-02-27 07:01:30+00:00    diptaabid
# 4    2023-02-27 06:51:03+00:00      sooibnc
# ...                        ...          ...
# 4995 2023-02-08 02:20:42+00:00     zenizzze
# 4996 2023-02-08 02:19:32+00:00  dystosaster
# 4997 2023-02-08 02:18:48+00:00  DaryonoBMKG
# 4998 2023-02-08 02:18:10+00:00      aldeetr
# 4999 2023-02-08 02:13:25+00:00       inyjia
#
#                                                   Tweet
# 0     Gempa bumi dan update status adalah hal yg tid...
# 1     Bantuan Kemanusiaan Untuk Korban Gempa Turki \...
# 2                                            GEMPA GASI
# 3                                    Sudirman gempa nih
# 4                                     loh tadi gempa ya
# ...                                                 ...
# 4995  dari jam 7 pagi ampe jam 9 nangisin kucing yg ...
# 4996  I will never get ready if JKT kena gempa 8-9 S...
# 4997  Adalah angan angan kosong, mengkait-kaitkan ge...
# 4998  Beberapa hari terakhir info BMKG isinya berita...
# 4999  Ya Allah.. Ngeri bgt ngeliat video2 gempa di t...
#
# [5000 rows x 3 columns]

# %%
df
# Out:
#                           Date         User  \
# 0    2023-02-27 07:40:12+00:00     Nganuuuu
# 1    2023-02-27 07:23:11+00:00      GkPatuk
# 2    2023-02-27 07:04:02+00:00    peacheui_
# 3    2023-02-27 07:01:30+00:00    diptaabid
# 4    2023-02-27 06:51:03+00:00      sooibnc
# ...                        ...          ...
# 4995 2023-02-08 02:20:42+00:00     zenizzze
# 4996 2023-02-08 02:19:32+00:00  dystosaster
# 4997 2023-02-08 02:18:48+00:00  DaryonoBMKG
# 4998 2023-02-08 02:18:10+00:00      aldeetr
# 4999 2023-02-08 02:13:25+00:00       inyjia
#
#                                                   Tweet
# 0     Gempa bumi dan update status adalah hal yg tid...
# 1     Bantuan Kemanusiaan Untuk Korban Gempa Turki \...
# 2                                            GEMPA GASI
# 3                                    Sudirman gempa nih
# 4                                     loh tadi gempa ya
# ...                                                 ...
# 4995  dari jam 7 pagi ampe jam 9 nangisin kucing yg ...
# 4996  I will never get ready if JKT kena gempa 8-9 S...
# 4997  Adalah angan angan kosong, mengkait-kaitkan ge...
# 4998  Beberapa hari terakhir info BMKG isinya berita...
# 4999  Ya Allah.. Ngeri bgt ngeliat video2 gempa di t...
#
# [5000 rows x 3 columns]

# %%
# to save to csv
df.to_csv('gempa_tweets.csv')
