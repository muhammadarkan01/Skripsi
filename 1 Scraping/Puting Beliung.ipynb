# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

query = "puting beliung lang:id -filter:links -filter:replies"
tweets = []
limit = 10000


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])
        
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
print(df)
# Out:
# C:\Users\arkan\AppData\Local\Temp\ipykernel_16432\3562232132.py:16: FutureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# C:\Users\arkan\AppData\Local\Temp\ipykernel_16432\3562232132.py:16: FutureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
#                           Date           User  \
# 0    2023-02-27 07:01:02+00:00   makeumellovv
# 1    2023-02-27 04:49:15+00:00    rakkairvanp
# 2    2023-02-27 00:55:35+00:00  halooakumo00k
# 3    2023-02-26 22:57:55+00:00    AndiiTamvan
# 4    2023-02-26 22:27:59+00:00    ganadzkriii
# ...                        ...            ...
# 4995 2021-01-16 05:51:51+00:00    sasakspirit
# 4996 2021-01-16 03:04:06+00:00     ayezragiel
# 4997 2021-01-15 22:43:14+00:00       dsofwans
# 4998 2021-01-15 16:16:35+00:00     rafianajm_
# 4999 2021-01-15 14:07:16+00:00  Goodwindology
#
#                                                   Tweet
# 0     anginnya kenceng bgt jadi keinget scene di upi...
# 1                     Masuk angin, angin puting beliung
# 2     demi, keknya org yg rajin sekalipun kalo ngeli...
# 3     ni mak gw kalo ujan nye bukan puting beliung h...
# 4     sekola teh mau hujan, banjir bandang, tanah lo...
# ...                                                 ...
# 4995  Ramalan...Bulan February ada daerah yg terkena...
# 4996  Ya elah…baru juga puting beliung\nudah kaya gi...
# 4997  Angin puting beliung Cirebon, Sriwijaya Air ja...
# 4998  bnyk musibah di awal taun ini. angin putingbel...
# 4999  Gempa, banjir, longsor, kadang puting beliung....
#
# [5000 rows x 3 columns]

# %%
df
# Out:
#                           Date           User  \
# 0    2023-02-27 07:01:02+00:00   makeumellovv
# 1    2023-02-27 04:49:15+00:00    rakkairvanp
# 2    2023-02-27 00:55:35+00:00  halooakumo00k
# 3    2023-02-26 22:57:55+00:00    AndiiTamvan
# 4    2023-02-26 22:27:59+00:00    ganadzkriii
# ...                        ...            ...
# 4995 2021-01-16 05:51:51+00:00    sasakspirit
# 4996 2021-01-16 03:04:06+00:00     ayezragiel
# 4997 2021-01-15 22:43:14+00:00       dsofwans
# 4998 2021-01-15 16:16:35+00:00     rafianajm_
# 4999 2021-01-15 14:07:16+00:00  Goodwindology
#
#                                                   Tweet
# 0     anginnya kenceng bgt jadi keinget scene di upi...
# 1                     Masuk angin, angin puting beliung
# 2     demi, keknya org yg rajin sekalipun kalo ngeli...
# 3     ni mak gw kalo ujan nye bukan puting beliung h...
# 4     sekola teh mau hujan, banjir bandang, tanah lo...
# ...                                                 ...
# 4995  Ramalan...Bulan February ada daerah yg terkena...
# 4996  Ya elah…baru juga puting beliung\nudah kaya gi...
# 4997  Angin puting beliung Cirebon, Sriwijaya Air ja...
# 4998  bnyk musibah di awal taun ini. angin putingbel...
# 4999  Gempa, banjir, longsor, kadang puting beliung....
#
# [5000 rows x 3 columns]

# %%
# to save to csv
df.to_csv('puting beliung_tweets.csv')
