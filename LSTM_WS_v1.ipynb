# %% [markdown]
# ### LSTM - Weakly Supervised - cp3

# %% [markdown]
# Dataset Train = autolabelled + train, preprocessed

# %% [markdown]
# ## Import lib

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ## LSTM model building

# %%
# Load the training and testing data
train_data = pd.read_csv('preprocessed_combined_dataset_i.csv')
test_data = pd.read_csv('preprocessed_test.csv')

# Split the data into input and target
train_text = train_data['text'].values
train_labels = train_data['label'].values
test_text = test_data['text'].values
test_labels = test_data['label'].values

# Create a tokenizer and fit it on the training data
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(train_text)

# Convert the training and testing data into sequences of integers
train_sequences = tokenizer.texts_to_sequences(train_text)
test_sequences = tokenizer.texts_to_sequences(test_text)

# Pad the sequences to a fixed length
max_length = 100
train_data = pad_sequences(train_sequences, maxlen=max_length)
test_data = pad_sequences(test_sequences, maxlen=max_length)

# Define the LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(5000, 64, input_length=max_length),
    tf.keras.layers.LSTM(64, dropout=0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the training data
history = model.fit(train_data, train_labels, epochs=15, batch_size=32, validation_split=0.4)
# Out:
# Epoch 1/15
# 523/523 [==============================] - 19s 34ms/step - loss: 0.3751 - accuracy: 0.8259 - val_loss: 0.3657 - val_accuracy: 0.8459
# Epoch 2/15
# 523/523 [==============================] - 17s 33ms/step - loss: 0.2763 - accuracy: 0.8740 - val_loss: 0.3846 - val_accuracy: 0.8456
# Epoch 3/15
# 523/523 [==============================] - 17s 32ms/step - loss: 0.2362 - accuracy: 0.8957 - val_loss: 0.4028 - val_accuracy: 0.8478
# Epoch 4/15
# 523/523 [==============================] - 17s 33ms/step - loss: 0.2017 - accuracy: 0.9140 - val_loss: 0.4478 - val_accuracy: 0.8461
# Epoch 5/15
# 523/523 [==============================] - 17s 32ms/step - loss: 0.1686 - accuracy: 0.9287 - val_loss: 0.4442 - val_accuracy: 0.8425
# Epoch 6/15
# 523/523 [==============================] - 17s 32ms/step - loss: 0.1463 - accuracy: 0.9395 - val_loss: 0.5571 - val_accuracy: 0.8382
# Epoch 7/15
# 523/523 [==============================] - 17s 32ms/step - loss: 0.1307 - accuracy: 0.9473 - val_loss: 0.6046 - val_accuracy: 0.8352
# Epoch 8/15
# 523/523 [==============================] - 17s 32ms/step - loss: 0.1171 - accuracy: 0.9530 - val_loss: 0.6450 - val_accuracy: 0.8357
# Epoch 9/15
# 523/523 [==============================] - 17s 32ms/step - loss: 0.1042 - accuracy: 0.9577 - val_loss: 0.6913 - val_accuracy: 0.8326
# Epoch 10/15
# 523/523 [==============================] - 17s 32ms/step - loss: 0.0905 - accuracy: 0.9630 - val_loss: 0.7789 - val_accuracy: 0.8313
# Epoch 11/15
# 523/523 [==============================] - 17s 32ms/step - loss: 0.0831 - accuracy: 0.9655 - val_loss: 0.8122 - val_accuracy: 0.8303
# Epoch 12/15
# 523/523 [==============================] - 17s 33ms/step - loss: 0.0768 - accuracy: 0.9677 - val_loss: 0.8512 - val_accuracy: 0.8321
# Epoch 13/15
# 523/523 [==============================] - 17s 32ms/step - loss: 0.0725 - accuracy: 0.9719 - val_loss: 0.9234 - val_accuracy: 0.8248
# Epoch 14/15
# 523/523 [==============================] - 17s 33ms/step - loss: 0.0643 - accuracy: 0.9734 - val_loss: 0.9942 - val_accuracy: 0.8286
# Epoch 15/15
# 523/523 [==============================] - 17s 33ms/step - loss: 0.0618 - accuracy: 0.9753 - val_loss: 0.9518 - val_accuracy: 0.8295

# %% [markdown]
# ## pyplot graph

# %%
# plot learning rate (model accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['acc', 'val_acc'], loc='upper left')
plt.show()

# %%
# plot learning rate (model loss)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %% [markdown]
# ## Evaluation matrix

# %%
# Evaluate the model on the testing data
train_loss, train_acc = model.evaluate(train_data, train_labels)
print('Train accuracy:', train_acc)
# Evaluate the model on the testing data
test_loss, test_acc = model.evaluate(test_data, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 872/872 [==============================] - 8s 10ms/step - loss: 0.4060 - accuracy: 0.9228
# Train accuracy: 0.9227763414382935
# 57/57 [==============================] - 1s 9ms/step - loss: 1.0934 - accuracy: 0.8286
# Test accuracy: 0.8286189436912537

# %%
# Generate predictions on the testing data
y_pred = model.predict(test_data)
y_pred = np.round(y_pred).astype(int)

# Generate and print the classification report
print(classification_report(test_labels, y_pred))
# Out:
# 57/57 [==============================] - 1s 9ms/step
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       883
#            1       0.87      0.78      0.82       920
#
#     accuracy                           0.83      1803
#    macro avg       0.83      0.83      0.83      1803
# weighted avg       0.83      0.83      0.83      1803

# %%
# Generate and print the confusion matrix
conm = confusion_matrix(test_labels, y_pred)

# %%
plt.figure(figsize=(7, 5))
sns.heatmap(conm, annot=True, fmt='d', cmap='cool')
plt.show()
